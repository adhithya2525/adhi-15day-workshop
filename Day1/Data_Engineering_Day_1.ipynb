# %% [markdown]
# <a href="https://colab.research.google.com/github/adhithya2525/adhi-15day-workshop/blob/main/Day1/Data_Engineering_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('student_performance.csv')
print(df)
# Out:
#     student_id            name  age  gender        department  semester  \
# 0         1001    Aarav Sharma   19    Male  Computer Science         2
# 1         1002     Priya Patel   20  Female  Computer Science         2
# 2         1003     Rohit Verma   19    Male       Electronics         2
# 3         1004     Sneha Reddy   20  Female        Mechanical         2
# 4         1005      Arjun Nair   19    Male  Computer Science         2
# 5         1006     Meera Joshi   20  Female       Electronics         2
# 6         1007     Kiran Kumar   21    Male             Civil         2
# 7         1008     Divya Singh   19  Female  Computer Science         2
# 8         1009    Rahul Mishra   20    Male        Mechanical         2
# 9         1010      Ananya Das   19  Female  Computer Science         2
# 10        1011     Vikram Iyer   20    Male       Electronics         2
# 11        1012     Pooja Gupta   19  Female             Civil         2
# ...

# %%
print(df.head())
# Out:
#    student_id          name  age  gender        department  semester  \
# 0        1001  Aarav Sharma   19    Male  Computer Science         2
# 1        1002   Priya Patel   20  Female  Computer Science         2
# 2        1003   Rohit Verma   19    Male       Electronics         2
# 3        1004   Sneha Reddy   20  Female        Mechanical         2
# 4        1005    Arjun Nair   19    Male  Computer Science         2
#
#    math_score  science_score  english_score  programming_score  \
# 0          85             78             72                 91
# 1          76             82             88                 79
# 2          65             74             61                 55
# 3          70             80             75                 48
# 4          92             88             81                 95
#
#    attendance_percentage       city  admission_year
# 0                     92     Mumbai            2023
# 1                     87  Ahmedabad            2023
# ...

# %%
df.tail()
# Out:
#     student_id            name  age  gender        department  semester  \
# 25        1026      Rekha Nair   20  Female       Electronics         2
# 26        1027   Gaurav Shukla   21    Male  Computer Science         2
# 27        1028   Sunita Pillai   19  Female             Civil         2
# 28        1029      Nitin Jain   20    Male        Mechanical         2
# 29        1030  Akanksha Yadav   19  Female  Computer Science         2
#
#     math_score  science_score  english_score  programming_score  \
# 25          72             77             73                 63
# 26          84             79             75                 87
# 27          60             65             68                 39
# 28          75             76             70                 50
# 29          91             93             87                 94
#
#     attendance_percentage                city  admission_year
# 25                     82               Kochi            2023
# ...

# %%
print("shape:",df.shape)
# Out:
# shape: (30, 13)

# %%
print("shape:",df.shape[1])
# Out:
# shape: 13

# %%
print("columns:",df.columns.tolist())
# Out:
# columns: ['student_id', 'name', 'age', 'gender', 'department', 'semester', 'math_score', 'science_score', 'english_score', 'programming_score', 'attendance_percentage', 'city', 'admission_year']

# %%
print("shape:",df.dtypes)
# Out:
# shape: student_id                int64
# name                     object
# age                       int64
# gender                   object
# department               object
# semester                  int64
# math_score                int64
# science_score             int64
# english_score             int64
# programming_score         int64
# attendance_percentage     int64
# city                     object
# admission_year            int64
# dtype: object

# %%
df.describe()
# Out:
#         student_id        age  semester  math_score  science_score  \
# count    30.000000  30.000000      30.0   30.000000      30.000000
# mean   1015.500000  19.733333       2.0   76.066667      77.833333
# std       8.803408   0.739680       0.0   11.467896       8.554423
# min    1001.000000  19.000000       2.0   56.000000      61.000000
# 25%    1008.250000  19.000000       2.0   67.250000      71.250000
# 50%    1015.500000  20.000000       2.0   75.500000      78.000000
# 75%    1022.750000  20.000000       2.0   85.750000      83.750000
# max    1030.000000  21.000000       2.0   95.000000      93.000000
#
#        english_score  programming_score  attendance_percentage  admission_year
# count      30.000000          30.000000              30.000000            30.0
# mean       74.166667          67.600000              84.500000          2023.0
# std        10.003735          21.041175               9.379913             0.0
# ...

# %%
df.isnull().sum()
# Out:
# student_id               0
# name                     0
# age                      0
# gender                   0
# department               0
# semester                 0
# math_score               0
# science_score            0
# english_score            0
# programming_score        0
# attendance_percentage    0
# city                     0
# admission_year           0
# dtype: int64

# %%
df['name']
# Out:
# 0       Aarav Sharma
# 1        Priya Patel
# 2        Rohit Verma
# 3        Sneha Reddy
# 4         Arjun Nair
# 5        Meera Joshi
# 6        Kiran Kumar
# 7        Divya Singh
# 8       Rahul Mishra
# 9         Ananya Das
# 10       Vikram Iyer
# 11       Pooja Gupta
# 12        Suresh Rao
# 13     Kavya Nambiar
# 14       Ajay Tiwari
# 15      Ritu Agarwal
# 16      Manoj Pandey
# 17    Swati Kulkarni
# 18    Deepak Chauhan
# 19      Nisha Kapoor
# 20     Harish Pillai
# 21       Tanvi Mehta
# 22      Sanjay Dubey
# 23     Preeti Saxena
# 24         Amit Bose
# 25        Rekha Nair
# 26     Gaurav Shukla
# 27     Sunita Pillai
# 28        Nitin Jain
# 29    Akanksha Yadav
# Name: name, dtype: object

# %%
print(df['department'].unique())
df['department'].value_counts()
# Out:
# ['Computer Science' 'Electronics' 'Mechanical' 'Civil']
# department
# Computer Science    13
# Electronics          6
# Mechanical           6
# Civil                5
# Name: count, dtype: int64

# %%
df['department'].unique()
# Out:
# array(['Computer Science', 'Electronics', 'Mechanical', 'Civil'],
#       dtype=object)

# %%
df['department'].value_counts()
# Out:
# department
# Computer Science    13
# Electronics          6
# Mechanical           6
# Civil                5
# Name: count, dtype: int64

# %%
cs_stu=df[df['department']=='Computer Science']

# %%
print(cs_stu)
# Out:
#     student_id            name  age  gender        department  semester  \
# 0         1001    Aarav Sharma   19    Male  Computer Science         2
# 1         1002     Priya Patel   20  Female  Computer Science         2
# 4         1005      Arjun Nair   19    Male  Computer Science         2
# 7         1008     Divya Singh   19  Female  Computer Science         2
# 9         1010      Ananya Das   19  Female  Computer Science         2
# 12        1013      Suresh Rao   21    Male  Computer Science         2
# 14        1015     Ajay Tiwari   19    Male  Computer Science         2
# 17        1018  Swati Kulkarni   19  Female  Computer Science         2
# 19        1020    Nisha Kapoor   19  Female  Computer Science         2
# 21        1022     Tanvi Mehta   19  Female  Computer Science         2
# 24        1025       Amit Bose   19    Male  Computer Science         2
# 26        1027   Gaurav Shukla   21    Male  Computer Science         2
# ...

# %%
print(len(cs_stu))
# Out:
# 13

# %%
print(cs_stu[['name','math_score']])
# Out:
#               name  math_score
# 0     Aarav Sharma          85
# 1      Priya Patel          76
# 4       Arjun Nair          92
# 7      Divya Singh          88
# 9       Ananya Das          95
# 12      Suresh Rao          83
# 14     Ajay Tiwari          71
# 17  Swati Kulkarni          90
# 19    Nisha Kapoor          79
# 21     Tanvi Mehta          93
# 24       Amit Bose          86
# 26   Gaurav Shukla          84
# 29  Akanksha Yadav          91

# %%
dfcs_high_attendance=cs_stu[cs_stu['attendance_percentage']>90]
print(dfcs_high_attendance[['name','math_score','programming_score','attendance_percentage']])
# Out:
#               name  math_score  programming_score  attendance_percentage
# 0     Aarav Sharma          85                 91                     92
# 7      Divya Singh          88                 93                     96
# 9       Ananya Das          95                 97                     98
# 17  Swati Kulkarni          90                 92                     94
# 21     Tanvi Mehta          93                 96                     97
# 24       Amit Bose          86                 89                     91
# 29  Akanksha Yadav          91                 94                     95

# %%
sorted_df=df.sort_values(by=['department','programming_score'],ascending=[True, False])
top_performing_students=sorted_df.groupby('department').head(3)
display(top_performing_students[['department','name','programming_score']])
# Out:
# Top 3 Performing Students in Each Department (by Programming Score):
#           department           name  programming_score
# 11             Civil    Pooja Gupta                 44
# 22             Civil   Sanjay Dubey                 42
# 6              Civil    Kiran Kumar                 40
# 9   Computer Science     Ananya Das                 97
# 21  Computer Science    Tanvi Mehta                 96
# 4   Computer Science     Arjun Nair                 95
# 10       Electronics    Vikram Iyer                 72
# 15       Electronics   Ritu Agarwal                 69
# 25       Electronics     Rekha Nair                 63
# 23        Mechanical  Preeti Saxena                 53
# 13        Mechanical  Kavya Nambiar                 51
# 28        Mechanical     Nitin Jain                 50

# %%
df['math_avg_score']=df.groupby('department')['math_score'].mean()

# %%
df['average_subject_score'] = df[['math_score', 'science_score', 'english_score', 'programming_score']].mean(axis=1)
average_score_per_department = df.groupby('department')['average_subject_score'].mean()
print("Average Overall Score per Department:")
display(average_score_per_department)
# Out:
# Average Overall Score per Department:
# department
# Civil               58.950000
# Computer Science    85.038462
# Electronics         69.375000
# Mechanical          66.833333
# Name: average_subject_score, dtype: float64

# %%
df['total_score'] = df[['math_score', 'science_score', 'english_score', 'programming_score']].sum(axis=1)
dept_avgg=df.groupby('department')['total_score'].mean().round(2).sort_values(ascending=False)
print(dept_avgg)
# Out:
# department
# Computer Science    340.15
# Electronics         277.50
# Mechanical          267.33
# Civil               235.80
# Name: total_score, dtype: float64
